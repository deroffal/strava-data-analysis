# %% [markdown]
# # Activities
#
# Overview of my activities

# %%
import pandas as pd
activities = pd.read_json("data/activities.json")
display(activities)
# Out:
#      resource_state                                athlete  \
# 0                 2  {'id': 42223740, 'resource_state': 1}
# 1                 2  {'id': 42223740, 'resource_state': 1}
# 2                 2  {'id': 42223740, 'resource_state': 1}
# 3                 2  {'id': 42223740, 'resource_state': 1}
# 4                 2  {'id': 42223740, 'resource_state': 1}
# ..              ...                                    ...
# 287               2  {'id': 42223740, 'resource_state': 1}
# 288               2  {'id': 42223740, 'resource_state': 1}
# 289               2  {'id': 42223740, 'resource_state': 1}
# 290               2  {'id': 42223740, 'resource_state': 1}
# 291               2  {'id': 42223740, 'resource_state': 1}
#
#                                                   name  distance  moving_time  \
# 0              Dernière course le long de la Chézine 😥   13395.5         4273
# 1                            Foulées du Numérique 2022   19245.5         5624
# ...
